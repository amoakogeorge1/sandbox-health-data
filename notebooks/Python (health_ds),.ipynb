# %%
import pandas as pd
import numpy as np

# create a fake dataset
data = pd.DataFrame({
    "patient_id": [1,2,3,4,5],
    "blood_pressure": [120, 130, 125, 140, 135],
    "age": [25, 30, 28, 35, 40]
})

print(data)
# Out:
#    patient_id  blood_pressure  age
# 0           1             120   25
# 1           2             130   30
# 2           3             125   28
# 3           4             140   35
# 4           5             135   40
